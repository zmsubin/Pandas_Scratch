# %%
import waterfall_chart
waterfall_chart.plot(['x', 'y'], [10, 20])
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\zachary.subin\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
waterfall_chart.plot(['x', 'y', 'z'], [10, 20, -40])
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\zachary.subin\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>
