# %%
import waterfall_chart
measure_names = ['Reference', 'Renewables', 'Light-Duty Vehicle Electrification', 'Heat Pumps', 'Non-Combustion', 'Other']
measure_quantities = [433, -103, -57, -27, -51, 86.2-433+(103+57+27+51)]
plot = waterfall_chart.plot(measure_names, measure_quantities, rotation_value=70, figsize=(7, 7),
                           net_label='2050 Goal', Title='CA GHG Emissions in 2050', y_lab = r'MMT CO$_2$e',
                           green_color = 'red', red_color = 'green', formatting='{:,.0f}')

# %%
waterfall_chart.__file__
# Out:
# 'C:\\Users\\zachary.subin\\AppData\\Local\\Continuum\\anaconda3\\lib\\site-packages\\waterfall_chart.py'
